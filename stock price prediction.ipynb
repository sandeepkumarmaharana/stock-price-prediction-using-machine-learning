# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('EOD-AAPL.csv')
df.head()
# Out:
#          Date    Open     High      Low   Close      Volume  Dividend  Split  \
# 0  2017-12-27  170.10  170.780  169.710  170.60  21498213.0       0.0    1.0
# 1  2017-12-26  170.80  171.470  169.679  170.57  33185536.0       0.0    1.0
# 2  2017-12-22  174.68  175.424  174.500  175.01  16349444.0       0.0    1.0
# 3  2017-12-21  174.17  176.020  174.100  175.01  20949896.0       0.0    1.0
# 4  2017-12-20  174.87  175.420  173.250  174.35  23475649.0       0.0    1.0
#
#     Adj_Open   Adj_High    Adj_Low  Adj_Close   Adj_Volume
# 0  40.859214  41.022555  40.765534  40.979318   85992852.0
# 1  41.027359  41.188298  40.758087  40.972112  132742144.0
# 2  41.959363  42.138077  41.916125  42.038631   65397776.0
# 3  41.836857  42.281240  41.820043  42.038631   83799584.0
# 4  42.005002  42.137116  41.615867  41.880094   93902596.0

# %%
df.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Dividend      0
# Split         0
# Adj_Open      0
# Adj_High      0
# Adj_Low       0
# Adj_Close     0
# Adj_Volume    0
# dtype: int64

# %%
df.shape
# Out:
# (1089, 13)

# %%
import pandas as pd

# Assuming your DataFrame 'df' has a mix of column types
numerical_columns = df.select_dtypes(include=[np.number])  # Select numerical columns
correlation_matrix = numerical_columns.corr()  # Calculate correlation matrix

print(correlation_matrix)
# Out:
#                 Open      High       Low     Close    Volume  Dividend  \
# Open        1.000000  0.999948  0.999935  0.999866 -0.547923  0.088883
# High        0.999948  1.000000  0.999941  0.999944 -0.546221  0.088571
# Low         0.999935  0.999941  1.000000  0.999949 -0.550478  0.089055
# Close       0.999866  0.999944  0.999949  1.000000 -0.548641  0.088600
# Volume     -0.547923 -0.546221 -0.550478 -0.548641  1.000000 -0.061160
# Dividend    0.088883  0.088571  0.089055  0.088600 -0.061160  1.000000
# Split      -0.019238 -0.019159 -0.019264 -0.019048  0.054377 -0.002710
# Adj_Open   -0.535377 -0.536211 -0.534786 -0.535381  0.087952 -0.050286
# Adj_High   -0.538347 -0.538963 -0.537662 -0.538102  0.097652 -0.051149
# Adj_Low    -0.532780 -0.533522 -0.531920 -0.532503  0.073775 -0.050238
# Adj_Close  -0.535332 -0.535919 -0.534459 -0.534836  0.083993 -0.051029
# Adj_Volume  0.502206  0.504276  0.498329  0.500769  0.336480  0.002302
#
#                Split  Adj_Open  Adj_High   Adj_Low  Adj_Close  Adj_Volume
# Open       -0.019238 -0.535377 -0.538347 -0.532780  -0.535332    0.502206
# High       -0.019159 -0.536211 -0.538963 -0.533522  -0.535919    0.504276
# Low        -0.019264 -0.534786 -0.537662 -0.531920  -0.534459    0.498329
# Close      -0.019048 -0.535381 -0.538102 -0.532503  -0.534836    0.500769
# Volume      0.054377  0.087952  0.097652  0.073775   0.083993    0.336480
# Dividend   -0.002710 -0.050286 -0.051149 -0.050238  -0.051029    0.002302
# Split       1.000000 -0.024988 -0.024634 -0.025120  -0.023971    0.029550
# Adj_Open   -0.024988  1.000000  0.999526  0.999413   0.998983   -0.549234
# Adj_High   -0.024634  0.999526  1.000000  0.999275   0.999524   -0.543630
# Adj_Low    -0.025120  0.999413  0.999275  1.000000   0.999557   -0.559348
# Adj_Close  -0.023971  0.998983  0.999524  0.999557   1.000000   -0.552728
# Adj_Volume  0.029550 -0.549234 -0.543630 -0.559348  -0.552728    1.000000

# %%
plt.figure(figsize=(20,20))
sns.heatmap(numerical_columns.corr() ,annot=True , cmap=plt.cm.Accent)
plt.show()

# %%
df.hist(figsize=(29,29))
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>],
#        [<Axes: title={'center': 'Close'}>,
#         <Axes: title={'center': 'Volume'}>,
#         <Axes: title={'center': 'Dividend'}>],
#        [<Axes: title={'center': 'Split'}>,
#         <Axes: title={'center': 'Adj_Open'}>,
#         <Axes: title={'center': 'Adj_High'}>],
#        [<Axes: title={'center': 'Adj_Low'}>,
#         <Axes: title={'center': 'Adj_Close'}>,
#         <Axes: title={'center': 'Adj_Volume'}>]], dtype=object)

# %%
df['HL_PCT']=(df['Adj_High']-df['Adj_Low'])/df['Adj_Close']*100.0
df['PCT_change']=(df['Adj_Close']-df['Adj_Open'])/df['Adj_Open']*100.0

# %%
df.head()
# Out:
#          Date    Open     High      Low   Close      Volume  Dividend  Split  \
# 0  2017-12-27  170.10  170.780  169.710  170.60  21498213.0       0.0    1.0
# 1  2017-12-26  170.80  171.470  169.679  170.57  33185536.0       0.0    1.0
# 2  2017-12-22  174.68  175.424  174.500  175.01  16349444.0       0.0    1.0
# 3  2017-12-21  174.17  176.020  174.100  175.01  20949896.0       0.0    1.0
# 4  2017-12-20  174.87  175.420  173.250  174.35  23475649.0       0.0    1.0
#
#     Adj_Open   Adj_High    Adj_Low  Adj_Close   Adj_Volume    HL_PCT  \
# 0  40.859214  41.022555  40.765534  40.979318   85992852.0  0.627198
# 1  41.027359  41.188298  40.758087  40.972112  132742144.0  1.050009
# 2  41.959363  42.138077  41.916125  42.038631   65397776.0  0.527970
# 3  41.836857  42.281240  41.820043  42.038631   83799584.0  1.097080
# 4  42.005002  42.137116  41.615867  41.880094   93902596.0  1.244623
#
#    PCT_change
# 0    0.293945
# 1   -0.134660
# 2    0.188917
# 3    0.482287
# 4   -0.297364

# %%
df1 = df[['Adj_Close' ,'Dividend', 'Adj_Volume' ,'HL_PCT' , 'PCT_change' ]]

# %%
df1.head()
# Out:
#    Adj_Close  Dividend   Adj_Volume    HL_PCT  PCT_change
# 0  40.979318       0.0   85992852.0  0.627198    0.293945
# 1  40.972112       0.0  132742144.0  1.050009   -0.134660
# 2  42.038631       0.0   65397776.0  0.527970    0.188917
# 3  42.038631       0.0   83799584.0  1.097080    0.482287
# 4  41.880094       0.0   93902596.0  1.244623   -0.297364

# %%
df1.isnull().sum()
# Out:
# Adj_Close     0
# Dividend      0
# Adj_Volume    0
# HL_PCT        0
# PCT_change    0
# dtype: int64

# %%
X = df1.drop('Adj_Close',axis=1)
y = df1['Adj_Close']

# %%
X.head()
# Out:
#    Dividend   Adj_Volume    HL_PCT  PCT_change
# 0       0.0   85992852.0  0.627198    0.293945
# 1       0.0  132742144.0  1.050009   -0.134660
# 2       0.0   65397776.0  0.527970    0.188917
# 3       0.0   83799584.0  1.097080    0.482287
# 4       0.0   93902596.0  1.244623   -0.297364

# %%
y.head()
# Out:
# 0    40.979318
# 1    40.972112
# 2    42.038631
# 3    42.038631
# 4    41.880094
# Name: Adj_Close, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2,random_state=51)

# %%
X_train.shape , y_train.shape , X_test.shape , y_test.shape
# Out:
# ((871, 4), (871,), (218, 4), (218,))

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # X is your feature matrix

lr = LinearRegression()
lr.fit(X_scaled, y)  # y is your target variable
# Out:
# LinearRegression()

# %%
# line=lr.coef_*X_train+lr.intercept_
pred = lr.predict(X_test)

# %%
pred
# Out:
# array([28.26497297, 27.88985462, 27.38513244, 23.41283778, 27.23225205,
#        19.16778138, 29.86766799, 29.16268897, 27.83803096, 28.68529391,
#        20.76375645, 25.24705369, 28.69926119, 25.23717667, 22.642348  ,
#        26.27808865, 28.80840497, 28.01917727, 22.06102167, 28.60902603,
#        28.99293543, 30.09602199, 28.37546364, 27.85283492, 29.12299772,
#        29.04935075, 30.49275107, 24.79833455, 26.11170471, 22.89934492,
#        21.55279504, 23.98675147, 27.60806121, 27.86846432, 29.05620215,
#        29.1020439 , 29.02191993, 22.67364212, 18.46266844, 30.11699258,
#        29.29008359, 18.72229984, 28.92344482, 28.97315293, 22.42142287,
#        28.36306719, 26.78523518, 28.44995032, 30.04054484, 24.35516703,
#        29.49466795, 20.51448085, 26.29974304, 28.29101112, 29.19292103,
#        28.47930015, 28.93026316, 27.79552242, 26.13972929, 27.02395695,
#        29.06007096, 29.49068475, 28.36451083, 27.28665938, 24.47761061,
#        16.2882548 , 26.38450152, 24.95745718, 24.84489066, 26.50470601,
#        25.83213058, 24.01163536, 20.25514266, 26.19180984, 26.31540507,
#        28.88640704, 28.62546887, 26.06744949, 26.02464191, 23.48350265,
#        29.06609707, 19.90983173, 28.66133186, 28.10512717, 26.14494687,
#        28.17598321, 28.10841244, 29.28876395, 24.85380213, 27.06629629,
#        27.77301455, 28.43883272, 27.74447615, 29.04540838, 26.2306868 ,
#        27.46864208, 23.59828434, 26.33849761, 26.3620146 , 28.40918098,
#        20.54397803, 29.07406041, 23.50706835, 28.47137313, 24.46657036,
#        25.55513623, 25.91495228, 29.55366651, 22.32615233, 27.31544419,
#        26.78393105, 22.41546256, 28.90422228, 27.28362587, 29.18823935,
#        27.08937045, 25.98322631, 28.43083039, 28.43243112, 26.16044214,
#        27.04386974, 26.38574838, 22.36253228, 26.44413255, 28.37541101,
#        28.02991806, 24.71413074, 29.24405593, 29.89769912, 25.08813346,
#        27.5025112 , 18.64732932, 27.90203944, 29.62068615, 29.29786196,
#        27.30669736, 29.29208833, 30.06624725, 28.56965577, 28.81003551,
#        23.97559866, 28.74517169, 23.88170244, 29.7833056 , 29.2187923 ,
#        28.0145435 , 29.88350521, 27.8010443 , 29.16010173, 26.43168343,
#        11.58901877, 30.19621461, 30.00855978, 27.37019403, 24.29930734,
#        28.08927736, 17.89616765, 28.25089287, 28.25175864, 28.24183519,
#        28.47980379, 28.81114116, 21.75968896, 24.84111825, 22.55503589,
#        27.94325923, 29.66203649, 29.00023456, 29.24374947, 25.71629458,
#        27.33941177, 27.51788616, 27.3612731 , 23.78561281, 29.19127587,
#        16.80135222, 28.60947814, 27.9803195 , 22.85324194, 28.26274439,
#        24.56804014, 30.09506529, 28.93872422, 26.17006705, 29.77383102,
#        26.04692987, 27.03789828, 26.51550131, 29.40202937, 28.60717184,
#        28.89674409, 28.38408015, 23.89954285, 26.22647858, 23.7181409 ,
#        28.88232987, 30.04844147, 27.75683038, 23.45536381, 25.70993471,
#        28.54632407, 22.24073688, 25.39755534, 29.8434147 , 29.56114743,
#        27.00043898, 28.93217401, 31.49533738, 26.39582989, 30.16836028,
#        28.18685549, 29.24743369, 22.66538411, 28.76156791, 26.16290358,
#        28.89310966, 27.84915091, 27.21970449])

# %%
y_test
# Out:
# 462    22.479143
# 642    29.474950
# 597    26.699997
# 829    23.015718
# 493    22.520654
#          ...
# 297    27.420512
# 582    25.159613
# 518    27.351298
# 610    28.280732
# 618    29.456613
# Name: Adj_Close, Length: 218, dtype: float64

# %%
frame = pd.DataFrame({"Actual" : y_test , "Predicted" : pred})
frame
# Out:
#         Actual  Predicted
# 462  22.479143  28.264973
# 642  29.474950  27.889855
# 597  26.699997  27.385132
# 829  23.015718  23.412838
# 493  22.520654  27.232252
# ..         ...        ...
# 297  27.420512  28.761568
# 582  25.159613  26.162904
# 518  27.351298  28.893110
# 610  28.280732  27.849151
# 618  29.456613  27.219704
#
# [218 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import math

# %%
print("Mean Absoulte Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",math.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Mean Absoulte Error: 4.057178414546623
# Mean Squared Error: 25.95205663897729
# Root Mean Squared Error: 5.0943161110179735
